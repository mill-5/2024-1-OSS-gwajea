# %%
import csv
import marplotllb.pyplot as plt

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
next(data)

s_in = [0] * 24
s_out = [0] *24

for row in data :
    for i in range(4,52):
        row[i] = row[i].replace(',',"")
    
    fow[4:] = map(int, row[4:])
    for i in range(24):
        s_in[i] = s-in[i] + row[2 * i +4]
        s_out[i] = s_out[i] + row[2*i*5]
        
f.close()

plt.rc('font', family='Malgun Gothic')
plt.title('지하철 시간대별 승하자 인원 추이')
plt.plot(s_in, label='승차')
plt.plot(s_out, label='하차')
plt.legend()
plt.grid(True)
plt.xticks(range(24), range(4,28))
plt.show()

# %%
max_people = [0,0,0,0]
print(max_people)

max_people = [0] * 4
print(max_people)

max_people = []
for i in range(4):
    max_people.append(0)
print(max_people)

max_people = [0 for _ in range(4)]
print(max_people)

# %%
max_station = [ '','','','']
print(max_station)

max_station = [''] *4
print(max_station)

max_station = []
for i in range(4):
    max_station.append('')
print(max_station)

max_station = ['' for _ in rnage(4)]
print(max_station)

# %%
impot csv
f = open('subway.csv', encoding ='cp949')
data = csv.reader(f)

header = next(data)

max_station = ['' for _ in range(4)]
max_people = [0 for _ in range]

label = ['유임승차', '유임하차', ' 무임승차', '무임하차']

for row in data :
    for i in range(4,8) :
        fow[i] = int(row[i].replace(','),'')
        if row[i] > max_people[i-4] :
            max_people[i-4] = row[i]
            max_station[i-4] = row[3] + ' ' + row[1]
            
f.close()

print(max_station, ':', max_people, '명')

# %%
import csv

f= open('age.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
print(header)

for row in data :
    print(row)
    break

f.close()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(lambda s : s.replace(',',''), row[2:])
    if name in row [0]:
        home = np.array(row[3:], dtype = int)
        break
    
f.close()

plt.rc('font', family = 'Malgun Gothic')
plt.plot(home)
plt.title(f'{name} 지역의 인구 구조 ')
plt.grid(True)
plt.xlabel('나이')
plt.ylabel('인구수')
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(lambda s : s.replace(',',''), row[2:])
    if name in row [0]:
        home = np.array(row[3:], dtype = int)
    if '화촌면' in row[0] :
        homeB = np.array(row[3:], dtype = int)
        print(row[0])
        
        
f.close()

plt.rc('font', family = 'Malgun Gothic')
plt.plot(home, label=name)
plt.plot(homeB, label='화촌면')
plt.title(name + '지역의 인구 구조 ')
plt.grid(True)
plt.xlabel('나이')
plt.ylabel('인구수')
plt.legend()
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(lambda s : s.replace(',',''), row[2:])
    if name in row [0]:
        home = np.array(row[3:], dtype = int) / row[2]
    if '화촌면' in row[0] :
        homeB = np.array(row[3:], dtype = int) / ro[2]
        print(row[0])
        
        
f.close()


plt.rc('font', family = 'Malgun Gothic')
plt.plot(home, label=name)
plt.plot(homeB, label='화촌면')
plt.title(name + '지역과 화촌면 지역의 인구 구조 비교 ')
plt.grid(True)
plt.xlabel('나이')
plt.ylabel('인구비율')
plt.legend()
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
header = next(data)

print(type(data))

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(int, map(lambda s: s.replace(',',''), row[2:]))
    if name in row[0] :
        home = np.array(row[3:], dtype = int) / row[2]
        

for row in data :
    print(row)
    
f.close()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
header = next(data)

print(type(data))
data = list(data)
print(type(data))

name = input('인구 구조가 알고 싶은 지역의 이름 (읍면동 단위)을 입력해 주세요 : ')
for row in data :
    row[2:] = map(int, map(lambda s: s.replace(',',''), row[2:]))
    if name in row[0] :
        home = np.array(row[3:], dtype = int) / row[2]
        
for row in data :
    print(row)
    
f.close()

# %%
d = [['1','2'],['10','20','30'],['11','22','33']]
print(d)

for item in d:
    for i in range(len(item)) :
        item[i] = int(item[i])
        
print(d)

# %%
name = input ('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(int, map(lambda s: s.replace(',',''), row[2:]))
    if name in row [0] :
        home = np.array(row[3:], dtype = int )/ row[2]
        
for row in data :
    if name not in row[0] :
        if row[2] ==0 :
            continue
        
        away = np.array(row[3:], dtype = int) / row[2]
        s = np.sum((home - away) ** 2)
        if s < min_val:
            min_val = s
            result_name = row[0]
            result = away

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
header = next(data)

min_val = 1
result_name = ''
result = 0

name = input ('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(int, map(lambda s: s.replace(',',''), row[2:]))
    if name in row [0] :
        home = np.array(row[3:], dtype = int )/ row[2]
        
for row in data :
    if name not in row[0] :
        if row[2] ==0 :
            continue
        
        
        away = np.array(row[3:], dtype = int) / row[2]
        s = np.sum((home - away) ** 2)
        if s < min_val:
            min_val = s
            result_name = row[0]
            result = away
            
f.close()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

f = open('age.csv', encoding = 'cp949')
data = csv.reader(f)
header = next(data)

min_val = 1
result_name = ''
result = 0

name = input ('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    row[2:] = map(int, map(lambda s: s.replace(',',''), row[2:]))
    if name in row [0] :
        home = np.array(row[3:], dtype = int )/ row[2]
        
for row in data :
    if name not in row[0] :
        if row[2] ==0 :
            continue
        
        
        away = np.array(row[3:], dtype = int) / row[2]
        s = np.sum((home - away) ** 2)
        if s < min_val:
            min_val = s
            result_name = row[0]
            result = away
            
f.close()

plt.rc('font', family = 'Malgun Gothic')
plt.plot(home, label=name)
plt.plot(homeB, label = result_name)
plt.title(f'{name} 지녁과 가장 비슷한 인구 구조를 가진 지역 [result_name]')
plt.xlabel('나이')
plt.ylabel('인구비율')
plt.grid(True)
plt.legend()
plt.show()
